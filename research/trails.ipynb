# %%
import yaml

# %%
yaml_file_path = "test.yaml"

with open(yaml_file_path, 'r') as yaml_file:
    data = yaml.safe_load(yaml_file)
print(data)
# Out:
# {'name': 'nagarathna', 'email': 'nagarathnakjprm1@gmail.com'}

# %%
data['name']
# Out:
# 'nagarathna'

# %%
from box import ConfigBox
d=ConfigBox(data)
d.name
# Out:
# 'nagarathna'
